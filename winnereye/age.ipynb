# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('dgul-template.xlsx')

# %%
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="C:\Windows\Fonts\H2HDRM.TTF").get_name()
rc('font', family=font_name)

# %%
data.columns
# Out:
# Index(['기사 작정실', 'URL', '현재댓글', '작성자삭제', '규정미준수', '남자', '여자', '10대', '20대',
#        '30대', '40대', '50대', '60대'],
#       dtype='object')

# %%
data.index=['1건', '2건', '3건', '4건', '5건']

# %%
data_mean = data[['남자','여자']].mean()

# %%
data_mean_columns = ['남자','여자']

# %%
plt.pie(data_mean, labels=data_mean_columns, autopct='%.1f%%')
plt.show()

# %%
data_age = data[['10대', '20대','30대', '40대', '50대', '60대']]

# %%
data_age.columns
# Out:
# Index(['10대', '20대', '30대', '40대', '50대', '60대'], dtype='object')

# %%
data_age.iloc[0,:]
# Out:
# 10대    0.01
# 20대    0.01
# 30대    0.05
# 40대    0.24
# 50대    0.43
# 60대    0.27
# Name: 1건, dtype: float64

# %%
data_age.to_excel('report.xlsx')

# %%
x = data_age.columns.tolist()

# %%
y = data_age.iloc[0,:].values.tolist()

# %%
plt.title("뉴스댓글 평균연령")
plt.xlabel("연령")
plt.ylabel("응답 비율(%)")
plt.ylim(0, 0.5)
plt.bar(x, y)
plt.show()
