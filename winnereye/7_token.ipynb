# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/winnereye/blob/main/dgul/7_token.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m pip install mysql-connector-python
# !pip install PyMySQL==1.0.0
# !pip install SQLAlchemy==1.4.17
# !pip install cryptography
# Out:
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.7/dist-packages)
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.7/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.7/dist-packages)
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.7/dist-packages)
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.7/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.7/dist-packages)
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.7/dist-packages)
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.7/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.7/dist-packages)
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.7/dist-packages)
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.7/dist-packages)
# ...

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import re

# %%
DATABASE = 'winnereye'

# %%
# 연결

db = pymysql.connect(
  host='18.177.137.112', 
  port=3306, 
  user='winnereye', 
  passwd='Whd1347!1', 
  db=DATABASE, charset='utf8',autocommit=True)

# %%
sql = "SELECT News_ID from winnereye.dgul_analysis_윤석열_20220101;"
df = pd.read_sql_query(sql, db)

# %%
import re

def remove_white_space(text):
    text = re.sub(r'[\t\r\n\f\v]', ' ', str(text))
    return text

def remove_special_char(text):
    text = re.sub('[^ ㄱ-ㅣ가-힣]+', ' ', str(text))
    return text

# %%
#df.News_ID = df.News_ID.apply(remove_special_char)

# %%
list_keyword = df['News_ID'].str.split(' ', expand=False).sum()[:10]

# %%
#!pip install -U torchtext==0.10.0

# %%
#import torchtext
#from torchtext.legacy.data import Field

def tokenizer(text):
    text = re.sub('[\[\]\(\)\"\']', '', str(text))
    text = text.split(', ')
    return text

#TEXT = Field(tokenize=tokenizer)

# %%
list_keyword
# Out:
# ['2', '이준석', '"윤석열,', '가만히', '있으면', '이길', '것', '같다"종합', '국정농담', '기업']

# %%
list_keyword = tokenizer(list_keyword)

# %%
list_keyword
# Out:
# ['2', '이준석', '윤석열,', '가만히', '있으면', '이길', '것', '같다종합', '국정농담', '기업']

# %%
# 해제
db.close()

# %% [markdown]
# ['', '', '이준석', '', '윤석열', '', '가만히', '있으면', '이길', '것']
