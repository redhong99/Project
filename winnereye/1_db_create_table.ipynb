# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/winnereye/blob/main/dgul/1_db_create_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!python -m pip install mysql-connector-python

# %%
search = '이재명'
period_start = '20220225'
period_end = '20220225'

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="18.177.137.112",
  user="winnereye",
  password="Whd1347!1",
  database="winnereye"
)

#print(mydb)

# %%
mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('alio',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
# ('winnereye',)

# %% [markdown]
# ### CREATE DATABASE

# %%
#mycursor = mydb.cursor()

#mycursor.execute("CREATE DATABASE winnereye")

# %% [markdown]
# ### CREATE TABLE

# %%
mycursor.execute("use winnereye")

# %%
mycursor = mydb.cursor()

# %%
table_name = 'dgul_analysis_{0}_{1}'.format(search, period_end)

# %%
'''
    "CREATE TABLE %s ( \
      News_ID varchar(512), \
      News_Date int, \
      URL varchar(512), \
      Dgul_now int, \
      Dgul_delete int, \
      Dgul_disqualified int, \
      Temp_store varchar(100), \
      Gender_Male int, \
      Gender_Female int, \
      Ages_10 int, \
      Ages_20 int, \
      Ages_30 int, \
      Ages_40 int, \
      Ages_50 int, \
      Ages_60 int  \
      );" % (table_name)
      '''
# Out:
# '\n    "CREATE TABLE %s (       News_ID varchar(512),       News_Date int,       URL varchar(512),       Dgul_now int,       Dgul_delete int,       Dgul_disqualified int,       Temp_store varchar(100),       Gender_Male int,       Gender_Female int,       Ages_10 int,       Ages_20 int,       Ages_30 int,       Ages_40 int,       Ages_50 int,       Ages_60 int        );" % (table_name)\n      '

# %%
mycursor.execute("CREATE TABLE %s ( \
      News_ID varchar(512), \
      News_Date int, \
      URL varchar(512), \
      Dgul_now int, \
      Dgul_delete int, \
      Dgul_disqualified int, \
      Temp_store varchar(100), \
      Gender_Male int, \
      Gender_Female int, \
      Ages_10 int, \
      Ages_20 int, \
      Ages_30 int, \
      Ages_40 int, \
      Ages_50 int, \
      Ages_60 int  \
      );" % (table_name) )
#    News_ID int, \
#    News_Date int, \
#    URL varchar(512));")

# %%
mycursor.execute("SHOW TABLES")

for x in mycursor:
  print(x)
# Out:
# ('dgul_analysis_안철수_20211201',)
# ('dgul_analysis_안철수_20211202',)
# ('dgul_analysis_안철수_20211203',)
# ('dgul_analysis_안철수_20211204',)
# ('dgul_analysis_안철수_20211205',)
# ('dgul_analysis_안철수_20211206',)
# ('dgul_analysis_안철수_20211207',)
# ('dgul_analysis_안철수_20211208',)
# ('dgul_analysis_안철수_20211209',)
# ('dgul_analysis_안철수_20211210',)
# ('dgul_analysis_안철수_20211211',)
# ('dgul_analysis_안철수_20211212',)
# ('dgul_analysis_안철수_20211213',)
# ('dgul_analysis_안철수_20211214',)
# ('dgul_analysis_안철수_20211215',)
# ('dgul_analysis_안철수_20211216',)
# ('dgul_analysis_안철수_20211217',)
# ('dgul_analysis_안철수_20211218',)
# ('dgul_analysis_안철수_20211219',)
# ('dgul_analysis_안철수_20211220',)
# ('dgul_analysis_안철수_20211221',)
# ('dgul_analysis_안철수_20211222',)
# ('dgul_analysis_안철수_20211223',)
# ('dgul_analysis_안철수_20211224',)
# ('dgul_analysis_안철수_20211225',)
# ('dgul_analysis_안철수_20211226',)
# ('dgul_analysis_안철수_20211227',)
# ('dgul_analysis_안철수_20211228',)
# ('dgul_analysis_안철수_20211229',)
# ...
